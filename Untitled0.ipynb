# %% [markdown]
# <a href="https://colab.research.google.com/github/NubiaVilela/N-bia-Vilela/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'coluna_1':[1.5,2.0,1.7,2.2,1.9],
        'coluna_2':[10.0,12.0,11.5,13.0,11.0],
        'coluna_3':[0,1,0,1,0],
        'coluna_4':[1,0,1,1,0],
        'coluna_5':[20.5,25.5,22.0,27.0,23.0]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    coluna_1  coluna_2  coluna_3  coluna_4  coluna_5
# 0       1.5      10.0         0         1      20.5
# 1       2.0      12.0         1         0      25.5
# 2       1.7      11.5         0         1      22.0
# 3       2.2      13.0         1         1      27.0
# 4       1.9      11.0         0         0      23.0

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/My Drive/Data/COMEXSTAT/'

# %%
arquivo_1 = origem + 'EXP_2025.csv'
arquivo_2 = origem + 'EXP_2026.csv'
ncm = origem + 'NCM.csv'
pais = origem + 'PAIS.csv'
vias = origem + 'VIA.csv'
urf = origem + 'URF.csv'

# %%
exp25 = pd.read_csv(arquivo_1,low_memory=False,sep=';',encoding='latin1')
exp26 = pd.read_csv(arquivo_2,low_memory=False,sep=';',encoding='latin1')
expncm = pd.read_csv(ncm,low_memory=False,sep=';',encoding='UTF-8')
exppais = pd.read_csv(pais,low_memory=False,sep=';',encoding='UTF-8')
expvias = pd.read_csv(vias,low_memory=False,sep=';',encoding='UTF-8')
expurf = pd.read_csv(urf,low_memory=False,sep=';',encoding='UTF-8')

# %%
exp25.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1709746 entries, 0 to 1709745
# Data columns (total 11 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1709746 non-null  int64
#  1   CO_MES      1709746 non-null  int64
#  2   CO_NCM      1709746 non-null  int64
#  3   CO_UNID     1709746 non-null  int64
#  4   CO_PAIS     1709746 non-null  int64
#  5   SG_UF_NCM   1709746 non-null  object
#  6   CO_VIA      1709746 non-null  int64
#  7   CO_URF      1709746 non-null  int64
#  8   QT_ESTAT    1709746 non-null  int64
#  9   KG_LIQUIDO  1709746 non-null  int64
#  10  VL_FOB      1709746 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 143.5+ MB

# %%
exp26.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125563 entries, 0 to 125562
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CO_ANO      125563 non-null  int64
#  1   CO_MES      125563 non-null  int64
#  2   CO_NCM      125563 non-null  int64
#  3   CO_UNID     125563 non-null  int64
#  4   CO_PAIS     125563 non-null  int64
#  5   SG_UF_NCM   125563 non-null  object
#  6   CO_VIA      125563 non-null  int64
#  7   CO_URF      125563 non-null  int64
#  8   QT_ESTAT    125563 non-null  int64
#  9   KG_LIQUIDO  125563 non-null  int64
#  10  VL_FOB      125563 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 10.5+ MB

# %%
expncm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13730 entries, 0 to 13729
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CO_NCM          13730 non-null  int64
#  1   CO_UNID         13730 non-null  int64
#  2   CO_SH6          13730 non-null  int64
#  3   CO_PPE          13426 non-null  float64
#  4   CO_PPI          13426 non-null  float64
#  5   CO_FAT_AGREG    13708 non-null  float64
#  6   CO_CUCI_ITEM    13730 non-null  object
#  7   CO_CGCE_N3      13730 non-null  int64
#  8   CO_SIIT         13426 non-null  float64
#  9   CO_ISIC_CLASSE  13730 non-null  int64
#  10  CO_EXP_SUBSET   13424 non-null  float64
#  11  NO_NCM_POR      13730 non-null  object
#  12  NO_NCM_ESP      13730 non-null  object
#  13  NO_NCM_ING      13730 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
exp_final = pd.concat([exp25,exp25], ignore_index=True)
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419492 entries, 0 to 3419491
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   CO_NCM      int64
#  3   CO_UNID     int64
#  4   CO_PAIS     int64
#  5   SG_UF_NCM   object
#  6   CO_VIA      int64
#  7   CO_URF      int64
#  8   QT_ESTAT    int64
#  9   KG_LIQUIDO  int64
#  10  VL_FOB      int64
# dtypes: int64(10), object(1)
# memory usage: 287.0+ MB

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2025       8  71039900       19      687        RS       4   817700
# 1    2025      12   2071412       10      741        SC       1   817800
# 2    2025      11  33059000       10      767        SP       4   817600
# 3    2025      11  56031330       10      845        SP       7  1017701
# 4    2025       6  21069090       10      365        SP       1   817800
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0     61690          13     203
# 1     83835       83835  111324
# 2       792         753   22012
# 3      2437        2437    8458
# 4      4800        4800   17304

# %%
exp_final.tail(5)
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 3419487    2025       5  85322410       11      247        SP       4  817600
# 3419488    2025       6   4079000       10      476        AP       1  240152
# 3419489    2025       4   2062990       10      434        AL       1  440151
# 3419490    2025       5  20091200       10      434        SP       1  817800
# 3419491    2025      12  23099090       10      628        PR       1  917800
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB
# 3419487     58000           1      95
# 3419488        90          90     415
# 3419489        10          10      62
# 3419490        36          36      95
# 3419491      2725        2725    5151

# %%
exppais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO_PAIS        281 non-null    int64
#  1   CO_PAIS_ISON3  281 non-null    int64
#  2   CO_PAIS_ISOA3  281 non-null    object
#  3   NO_PAIS        281 non-null    object
#  4   NO_PAIS_ING    281 non-null    object
#  5   NO_PAIS_ESP    281 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 13.3+ KB

# %%
exp_final = exp_final.merge(exppais[['CO_PAIS', 'NO_PAIS']], on='CO_PAIS', how="left")

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2025       8  71039900       19      687        RS       4   817700
# 1    2025      12   2071412       10      741        SC       1   817800
# 2    2025      11  33059000       10      767        SP       4   817600
# 3    2025      11  56031330       10      845        SP       7  1017701
# 4    2025       6  21069090       10      365        SP       1   817800
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB      NO_PAIS
# 0     61690          13     203  El Salvador
# 1     83835       83835  111324    Singapura
# 2       792         753   22012        Suíça
# 3      2437        2437    8458      Uruguai
# 4      4800        4800   17304    Indonésia

# %%
exp_final = exp_final.merge(expncm[['CO_NCM','NO_NCM_POR']],on='CO_NCM',how='left')

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2025       8  71039900       19      687        RS       4   817700
# 1    2025      12   2071412       10      741        SC       1   817800
# 2    2025      11  33059000       10      767        SP       4   817600
# 3    2025      11  56031330       10      845        SP       7  1017701
# 4    2025       6  21069090       10      365        SP       1   817800
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB      NO_PAIS  \
# 0     61690          13     203  El Salvador
# 1     83835       83835  111324    Singapura
# 2       792         753   22012        Suíça
# 3      2437        2437    8458      Uruguai
# 4      4800        4800   17304    Indonésia
#
#                                           NO_NCM_POR
# 0  Outras pedras preciosas (exceto diamantes) ou ...
# 1  Coxas com sobrecoxas não desossadas de galinha...
# 2                       Outras preparações capilares
# ...

# %%
coluna = 'NO_PAIS'
CP = exp_final[coluna].value_counts().sort_values(ascending=False)
print(f'Total de operações {coluna}:')
print(CP)
# Out:
# Total de operações NO_PAIS:
# NO_PAIS
# Paraguai                217888
# Argentina               215474
# Estados Unidos          195554
# Uruguai                 147198
# Panamá                  145172
#                          ...
# Aland, Ilhas                 2
# Santa Helena                 2
# Eritreia                     2
# Svalbard e Jan Mayen         2
# Coreia do Norte              2
# Name: count, Length: 245, dtype: int64

# %%
exp_final.to_csv(origem+'exp_final.csv',index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(14, 7))

sns.lineplot(x='Date', y='KG_LIQUIDO', data=monthly_imports, marker='o', color='teal', linewidth=2)


plt.xticks(
    monthly_imports['Date'],
    [d.strftime('%m/%Y') for d in monthly_imports['Date']],
    rotation=45
)


plt.title('Relação Eixo X (Todos os Meses) e Eixo Y (Volume KG)', fontsize=14)
plt.xlabel('Eixo X: Janeiro/2025 a Janeiro/2026', fontsize=12)
plt.ylabel('Eixo Y: Total de Importações (KG)', fontsize=12)


plt.ticklabel_format(style='plain', axis='y')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

plt.show()

# %%
print("\nTabela de Dados Consolidados:")
data_table.enable_dataframe_formatter()
display(monthly_imports[['CO_ANO', 'CO_MES', 'KG_LIQUIDO', 'Date']].head(13))
# Out:
# Tabela de Dados Consolidados:
#     CO_ANO  CO_MES   KG_LIQUIDO       Date
# 0     2025       1  15528918531 2025-01-01
# 1     2025       2  12973124624 2025-02-01
# 2     2025       3  13552151392 2025-03-01
# 3     2025       4  15468363520 2025-04-01
# 4     2025       5  15344449184 2025-05-01
# 5     2025       6  15016038003 2025-06-01
# 6     2025       7  17140340187 2025-07-01
# 7     2025       8  16785444660 2025-08-01
# 8     2025       9  17057560731 2025-09-01
# 9     2025      10  17463010828 2025-10-01
# 10    2025      11  14442750743 2025-11-01
# 11    2025      12  16102323647 2025-12-01
# 12    2026       1  14335725933 2026-01-01
